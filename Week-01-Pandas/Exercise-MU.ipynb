# %% [markdown]
# # First print your name in the cell below then save this file. (or something nice about your instructor)

# %%
# In this cell print your name 

print("Mohammed Uddin")
# Out:
# Mohammed Uddin

# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
df = pd.read_csv("data/listings.csv")
df
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
# ...

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 

len(df[df['price']<100])
# Out:
# 22778

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.

df_bk = df[df["neighbourhood_group"]=="Brooklyn"]
len(df_bk)
# Out:
# 18632

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

len(df_bk[df_bk['price']<100])
# Out:
# 10473

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
# How many total are there that have those names

len(df[df["host_name"].isin(["Michael","David","John","Daniel"])])
# Out:
# 1258

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before. 

df['adjusted_price'] = df['price']+100

# %%
df[['price','adjusted_price']]
# Out:
#        price  adjusted_price
# 0        175             275
# 1         75             175
# 2         60             160
# 3        175             275
# 4         65             165
# ...      ...             ...
# 46522    145             245
# 46523     87             187
# 46524     59             159
# 46525     80             180
# 46526     66             166
#
# [46527 rows x 2 columns]

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  

num_private = len(df[df['room_type']=='Private room'])
num_shared = len(df[df['room_type']=='Shared room'])
total = len(df)
percent_private = round(num_private / total * 100, 2)
percent_shared  = round(num_shared  / total * 100, 2)
print("Percent private: ", percent_private, "%")
print("Percent  shared: ", percent_shared,  "%")
# Out:
# Percent private:  45.44 %
# Percent  shared:  2.12 %

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.

dfg_n = df.groupby(['neighbourhood_group'])

# %%
dfg_n['id'].count()
# Out:
# neighbourhood_group
# Bronx             1183
# Brooklyn         18632
# Manhattan        20580
# Queens            5791
# Staten Island      341
# Name: id, dtype: int64

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 

pd.set_option("display.precision", 2)

dfg_n['price'].mean()
# Out:
# neighbourhood_group
# Bronx             92.75
# Brooklyn         120.23
# Manhattan        191.88
# Queens            99.75
# Staten Island    110.95
# Name: price, dtype: float64

# %%
# 2.5. Using `groupby`, find the mean price for each room_type. 

df.groupby(['room_type'])['price'].mean()
# Out:
# room_type
# Entire home/apt    199.40
# Hotel room         275.02
# Private room        91.45
# Shared room         87.06
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 

dfg_n['price'].agg(['min','max'])
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room_type in each neighbourhood_group.

dfg_4 = df.groupby(['neighbourhood_group','room_type'])

# %%
dfg_4['price'].mean()
# Out:
# neighbourhood_group  room_type
# Bronx                Entire home/apt    138.00
#                      Private room        68.42
#                      Shared room         66.39
# Brooklyn             Entire home/apt    171.59
#                      Hotel room         147.30
#                      Private room        71.29
#                      Shared room         57.87
# Manhattan            Entire home/apt    231.34
#                      Hotel room         292.52
#                      Private room       128.28
#                      Shared room        111.74
# Queens               Entire home/apt    150.17
#                      Hotel room         139.06
#                      Private room        69.97
#                      Shared room         89.89
# Staten Island        Entire home/apt    151.72
#                      Private room        70.31
#                      Shared room         46.00
# Name: price, dtype: float64

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.

dfg_4['price'].agg(['count','min','max','mean','median','std'])
# Out:
#                                      count  min    max    mean  median     std
# neighbourhood_group room_type
# Bronx               Entire home/apt    415   25   1404  138.00   103.0  126.03
#                     Private room       722   16    700   68.42    55.0   57.34
#                     Shared room         46   20    800   66.39    44.0  114.44
# Brooklyn            Entire home/apt   9112   20  10000  171.59   135.0  236.73
#                     Hotel room          30    0    399  147.30   129.0   91.15
#                     Private room      9159   10   2500   71.29    60.0   69.02
#                     Shared room        331   15   1500   57.87    36.0   92.22
# Manhattan           Entire home/apt  12209    0  10000  231.34   165.0  410.31
#                     Hotel room         351    0   2211  292.52   210.0  315.92
#                     Private room      7601   10  10000  128.28    80.0  448.68
# ...

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`

df_prices = pd.read_csv('data/prices.csv')
df_prices
# Out:
#   neighbourhood_group   mean_price
# 0               Bronx        92.75
# 1            Brooklyn       120.23
# 2           Manhattan       191.88
# 3              Queens        99.75
# 4       Staten Island       110.95

# %%
df_listings = pd.read_csv('data/n_listings.csv')
df_listings
# Out:
#   neighbourhood_group;n_listings
# 0                     Bronx;1183
# 1                 Brooklyn;18632
# 2                Manhattan;20580
# 3                LongIsland;4121

# %%
df_listings = pd.read_csv('data/n_listings.csv',sep=';')
df_listings
# Out:
#   neighbourhood_group  n_listings
# 0               Bronx        1183
# 1            Brooklyn       18632
# 2           Manhattan       20580
# 3          LongIsland        4121

# %%
# 2. Do join that keeps all the records for each table.

df_merge = pd.merge(df_prices,df_listings,on="neighbourhood_group",how="outer")

# %%
df_merge
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx        92.75      1183.0
# 1            Brooklyn       120.23     18632.0
# 2           Manhattan       191.88     20580.0
# 3              Queens        99.75         NaN
# 4       Staten Island       110.95         NaN
# 5          LongIsland          NaN      4121.0

# %%
filename = 'joined.csv'

# %%
df_merge.to_csv(filename,index=False)

# %%
df_import = pd.read_csv(filename)

# %%
df_import
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx        92.75      1183.0
# 1            Brooklyn       120.23     18632.0
# 2           Manhattan       191.88     20580.0
# 3              Queens        99.75         NaN
# 4       Staten Island       110.95         NaN
# 5          LongIsland          NaN      4121.0

# %% [markdown]
# # Extra Credit
# Every question below this cell is extra credit and optional.

# %% [markdown]
# ### 1. (Easy) Explore this new PandasAI Package and tell me what its all about because I've never used it.
# * https://www.youtube.com/watch?v=5w6eZaoDVVk&ab_channel=CodingIsFun
# * See if you can use it on the listings.csv to find out some cool info. or answer some of the questions above.

# %% [markdown]
# ### 2. (Very Easy) Find other cool Panda packages / add ons and show us what they can do well. And how you installed them.

# %% [markdown]
# ### 3. (Medium) Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
df_grammy = pd.read_csv('data/grammys.csv')

# %%
df_grammy
# Out:
#       year                                           category  \
# 0     1959                                  Album of the Year
# 1     1959                                   Best Album Cover
# 2     1959                                   Best Arrangement
# 3     1959  Best Classical Performance - Chamber Music (in...
# 4     1959  Best Classical Performance - Instrumentalist (...
# ...    ...                                                ...
# 6318  2019                                 Record of the Year
# 6319  2019                                   Song of the Year
# 6320  2019                                   Song of the Year
# 6321  2019                                   Song of the Year
# 6322  2019                                   Song of the Year
#
#                                  nominee  \
# 0             The Music from Peter Gunn.
# 1                        Only the Lonely
# 2              The Music From Peter Gunn
# 3                 Beethoven: Quartet 130
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
#1. Album of the Year 2016
df_grammy[(df_grammy['category']=='Album of the Year') & (df_grammy['year']==2016) & (df_grammy['winner'])]
#not sure if "who" means everyone that worked on it or not, or the album itself, can just add ['workers'] to the end
# Out:
#       year           category nominee  \
# 5505  2016  Album of the Year   1989.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      workers  \
# ...

# %%
#2. Best Rap Album 2009
df_grammy[(df_grammy['category']=='Best Rap Album') & (df_grammy['year']==2009) & (df_grammy['winner'])]
#not sure if album or rapper is the desired answer
# Out:
#       year        category         nominee     workers  winner
# 4396  2009  Best Rap Album  Tha Carter III  Lil' Wayne    True

# %%
df_kendrick = df_grammy[df_grammy['workers']=='Kendrick Lamar']
df_kendrick
# Out:
#       year              category                  nominee         workers  \
# 5269  2014        Best Rap Album  Good Kid, M.A.A.D City.  Kendrick Lamar
# 5272  2014  Best Rap Performance  Swimming Pools (Drank).  Kendrick Lamar
# 5448  2015  Best Rap Performance                       i.  Kendrick Lamar
# 5596  2016        Best Rap Album     To Pimp a Butterfly.  Kendrick Lamar
# 5599  2016  Best Rap Performance                 Alright.  Kendrick Lamar
# 6003  2018  Best Rap Performance                  HUMBLE.  Kendrick Lamar
#
#       winner
# 5269   False
# 5272   False
# 5448    True
# 5596    True
# 5599    True
# 6003    True

# %%
kendrick_mask = df_grammy['workers'].str.contains('Kendrick Lamar', case=False, na=False)

# %%
df_kendrick = df_grammy[kendrick_mask]
df_kendrick
# Out:
#       year                     category  \
# 5269  2014               Best Rap Album
# 5272  2014         Best Rap Performance
# 5448  2015         Best Rap Performance
# 5451  2015                Best Rap Song
# 5507  2016            Album of the Year
# 5575  2016             Best Music Video
# 5596  2016               Best Rap Album
# 5599  2016         Best Rap Performance
# 5602  2016                Best Rap Song
# 5604  2016                Best Rap Song
# 5605  2016  Best Rap/Sung Collaboration
# 5654  2017            Album of the Year
# 6000  2018               Best Rap Album
# 6003  2018         Best Rap Performance
# 6006  2018                Best Rap Song
# 6009  2018    Best Rap/Sung Performance
# 6087  2019            Album of the Year
# 6248  2019                Best Rap Song
# 6252  2019    Best Rap/Sung Performance
# 6317  2019           Record of the Year
#
#                                                    nominee  \
# ...

# %%
len(df_kendrick)
# Out:
# 20

# %%
len(df_kendrick[df_kendrick['winner']])
# Out:
# 11

# %% [markdown]
# Kendrick Lamar was part of 20 album nominations, 11 of which won awards

# %% [markdown]
# ### (Hard) Load the Game Logs for 2022 and add the column names using a dictionary.
# * [Link to the data page](https://www.retrosheet.org/gamelogs/)
# * [Link to the column names](https://procatinator.com/)
# * haha, gotta find them yourself!

# %% [markdown]
# ### (Extra Hard) Download the files for the past 5 years into a new folder and add them all into one data frame using pandas, then save that new file.
# * Try to not hard code in the file names. We want to do this programmatically because what if we want to add new/more file names in the future.
